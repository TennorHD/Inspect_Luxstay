# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path=r"C:\Users\Owner\Desktop\DS\chromedriver\chromedriver.exe")

# %%
name=[] #List to store name of the product
category=[]
description=[]
prices=[] #List to store price of the product
location=[] #List to store rating of the product

# %%
for i in range(200):
    driver.get("https://www.luxstay.com/s/?page={}".format(i+1))
    content = driver.page_source
    soup = BeautifulSoup(content)
    for a in soup.findAll('div', attrs={'class':'col-xs-6 col-md-3 col-lg-20'}):
        cat=a.find('div', attrs={'class':"promo__type bold"})
        des=a.find('div', attrs={'class':'promo__description my--6 text-lowercase'})
        tit=a.find('div', attrs={'class':'promo__title extra-bold'})
        pri=a.find('div', attrs={'class':'promo__price mb--6'})
        loc=a.find('div', attrs={'class':'promo__add mb--6 promo__add mb--6'})
        if cat == None:
            category.append('Invalid')
        else:
            category.append(cat.text)
        if tit == None:
            name.append('Invalid')
        else:
            name.append(tit.text)
        if des == None:
            description.append('Invalid')
        else:
            description.append(des.text)
        if pri == None:
            prices.append('Invalid')
        else:
            prices.append(pri.text)
        if loc == None:
            location.append('Invalid')
        else:
            location.append(loc.text)

# %%
# Out:
# 'Invalid'

# %%
import re
name_temp = []
for i in range(len(name)):
    if name[i] != 'Invalid':
        try:
            name_temp.append(re.split(r'\n            |\n          ',name[i])[1])
        except:
            print(i)
            break
    else:
        name_temp.append(name[i])
df1 = pd.DataFrame(name_temp,columns = ['name'])
print(df1)
# Out:
# ["San's Home [Sharing home]", 'Chillin House', 'MLibrary Pentstudio Apartment West Lake with Panorama View', 'Win Aparment Studio Tiêu chuẩn (Min 2 night) #1', '✦Luxury Villa 6BR✦Thao Dien Dist 2✦Bathtub✦Big yard✦Sai Gon River View [Sweethost]', '1 Bedroom with 15-minute walk to Xuan Huong Lake', 'Ann Retreat Resort Hội An- Phòng Grand Deluxe Cổ Điển View Sông Thu Bồn', '[BrotherhooD] Luxury Apartment 2BR / Big Balcony / 15 minutes to Hoan Kiem Lake', 'LINH HOMIE - Room with Window View', 'Fika No.1 ♥️ Free Breakfast, Netflix ♡  District 1', 'An Bang Memory 4 bedroom-Cottage at An Bang Beach', 'Thị Trấn Nhỏ Homestay - Phòng nhà xây trắng', 'Palm Luxury BeachSide Saltwater Pool Villa', 'A5 Melody Vung Tau Homestay (Smarthome)', 'Mimi House - Studio with Private Patio', 'Anna House - Newly modern room in the center (01)', 'Dear Homie Central Hotel', 'Merry Yard Homestay Dalat - 008', 'Lovely&Modern 2Brs Apt w/ Park View,Free Pool&Gym', 'Căn hộ gần sông Hàn, có ban công, view phố, smarthome 22', "San's Home [Sharing home]", 'Chillin House', 'MLibrary Pentstudio Apartment West Lake with Panorama View', 'Win Aparment Studio Tiêu chuẩn (Min 2 night) #1', '✦Luxury Villa 6BR✦Thao Dien Dist 2✦Bathtub✦Big yard✦Sai Gon River View [Sweethost]', '1 Bedroom with 15-minute walk to Xuan Huong Lake', 'Ann Retreat Resort Hội An- Phòng Grand Deluxe Cổ Điển View Sông Thu Bồn', '[BrotherhooD] Luxury Apartment 2BR / Big Balcony / 15 minutes to Hoan Kiem Lake', 'LINH HOMIE - Room with Window View', 'Fika No.1 ♥️ Free Breakfast, Netflix ♡  District 1', 'An Bang Memory 4 bedroom-Cottage at An Bang Beach', 'Thị Trấn Nhỏ Homestay - Phòng nhà xây trắng', 'Palm Luxury BeachSide Saltwater Pool Villa', 'A5 Melody Vung Tau Homestay (Smarthome)', 'Mimi House - Studio with Private Patio', 'Anna House - Newly modern room in the center (01)', 'Dear Homie Central Hotel', 'Merry Yard Homestay Dalat - 008', 'Lovely&Modern 2Brs Apt w/ Park View,Free Pool&Gym', 'Căn hộ gần sông Hàn, có ban công, view phố, smarthome 22', 'Big Home Dalat - Phòng đôi B1', 'THE MOON APARTMENT   ', 'Flame flowers homestay_Double View Garden ', 'Long 22 Vinhomes Metropolis Apartment #2BR LUXURY', 'Nice seaview apartment Blue Saphire Resort', 'Bespoke Villa Hoian - Deluxe Twin Room Garden view', 'Stay&Fun No.4 - 60m2 studio with great view, 5 minutes walking to every famous city sights', 'Spacious contemporary studio @ My khe beach', 'A Cosy Apartment in @Vinhomes Greenbay @1 bedroom Ha Noi', 'Orion Homestay - City View 2', 'WINDBELL VILLA / Garden view room 2', 'Nomad Home & Coffee - Phòng đôi Cam, WC riêng, ăn sáng', "Felix's home", 'SunSea Hotel&Villa', 'Maison De Lave | HOMESTAY | Jungle room-Han Brigde', 'CHIQUILLA BOUTIQUE HOUSE - BLANCO BUDGET CHARMING', 'Pinky House 23 căn hộ đầy đủ tiện nghi gần Hồ Hoàng Cầu', 'Ann Retreat Resort Hội An- Phòng Deluxe Sang Trọng View Phố Cổ', '✦ Luxury Villa 3BR ✦Thao Dien Dist 2✦Bathtub✦Big yard✦Sai Gon River View _[Sweethost]', 'Dốc.apartment coffee', 'Spotless Studio located perfectly in center HCMC', 'Deluxe Double Room/Queen Bed/Private Bathroom/Close to old town', 'SensesHouse5b', 'Betania Home Danang Beach, 2-bedroom, 2 balconies (501)', 'Cozy and Quiet Studio near Tien Son Bridge ', 'Lamer Homestay - phòng gia đình sân vườn', 'Mayli Homestay Đà Lạt - Phòng đôi 2 người City View - Khu biệt thự độc lập - 5p đến trung tâm', 'Soleil Apartment- Deluxe Double View', 'Apartment for rent with 1bedroom in Phan Xich Long Street', 'Betel Garden Villa', 'Bespoke Villa Hoi An - A Home sweet home in Acient Town', "Lam's Apartment (Superior 101)", 'Seasand Apartment Đà Nẵng', 'Westlake-Central-Apartments', 'Super Romantic Couple Nest - Luxurious Brandnew 76m2 ', 'Hana House - Cabbage Room', 'À côté de rive homestay-Cozy home,quite space,rooftop for BBQ,near Ancient area', '1 King bed_Bathtub@Partial Sea View', '[-20%] 1BR Amazing view, Clean room❤️Free Breakfast&Biclycle❤️Green Hill Villa Hoi An', '5BR, Fabulous villa for 10 people, Hoi An, Vietnam', 'Scan ...

# %%
cat_temp = []
for i in range(len(category)):
    if category[i] != 'Invalid':
        temp = re.split(r'\n        |\n         | ·  ',category[i])
        if len(temp)<2:
            cat_temp.append(('None','None'))
        elif len(temp)<4:
            cat_temp.append((temp[1],'None'))
        else:
            cat_temp.append((temp[1],temp[3]))
    else:
        cat_temp.append(('None','None'))
df2 = pd.DataFrame(cat_temp, columns = ['category','project'])
print(df2)

# %%
des_temp = []
for i in range(len(description)):
    if description[i] != 'Invalid':
        temp = re.split(r' guests · | guest · | Bedroom · | Bedrooms · | Bedrooms| Bedroom| bathrooms| bathroom',description[i])[0:3]
        temp = tuple([x if x else '0' for x in temp])
        des_temp.append(temp)
    else:
        des_temp.append(('0','0','0'))
df3 = pd.DataFrame(des_temp, columns = ['guest','bedroom','bathroom'])
print(df3)

# %%
pri_temp = []
for i in range(len(prices)):
    if prices[i] != 'Invalid':
        temp = re.split(r'/night \$|/night | \$',prices[i])
        if temp[2]:
            pri_temp.append((temp[1],'1',temp[2]))
        else:
            pri_temp.append((temp[1],'0','Invalid'))
    else:
        pri_temp.append(('0','0','Invalid'))
df4 = pd.DataFrame(pri_temp, columns = ['price','discounted','normal price'])
print(df4)

# %%
loc_temp = [tuple(re.split(r', ',location[i])) for i in range(len(location))]
df5 = pd.DataFrame(loc_temp, columns = ['province','state','country'])
print(df5)

# %%
print(len(name_temp),len(cat_temp),len(des_temp),len(pri_temp),len(loc_temp))

# %%
df = pd.concat([df1,df2,df3,df4,df5],axis = 1)
df.to_csv("./result200.csv",encoding='utf-8-sig')
df
